# %%
from selenium import webdriver
import time

options = webdriver.ChromeOptions()

# options.add_argument('headless')

# set the window size
options.add_argument('window-size=1200x600')

# initialize the driver
driver = webdriver.Chrome(chrome_options=options)

# https://www.linkedin.com/uas/login
driver.get('https://www.linkedin.com/uas/login')

username = driver.find_element_by_id('session_key-login')
password = driver.find_element_by_id('session_password-login')

username.send_keys('ryan@growthgenius.com')
password.send_keys('Gr0wthP1ease1!')

driver.find_element_by_name("signin").click()

import pandas as pd
df = pd.read_csv("GG Outbound LinkedIn (Ryan).csv")

# %%
# i = 0
# while (i < 3):
for x in df["Person Linkedin Url"].tolist():
    driver.get(x)
    time.sleep(10)
#     i = i + 1

    try:
            name = driver.find_element_by_xpath("//h1[@class='pv-top-card-section__name Sans-26px-black-85%']").text
            headline = driver.find_element_by_xpath("//h2[@class='pv-top-card-section__headline mt1 Sans-19px-black-85%']").text      
            location = driver.find_element_by_xpath("//h3[@class='pv-top-card-section__location Sans-17px-black-55%-dense mt1 inline-block']").text
            description = driver.find_element_by_css_selector('p.pv-top-card-section__summary-text').text
            pres_title = driver.find_element_by_css_selector('.pv-entity__summary-info h3:nth-of-type(1)').text
            pres_company = driver.find_element_by_css_selector('.pv-entity__secondary-title').text
            pres_date = driver.find_element_by_xpath("//h4[@class='pv-entity__date-range inline-block Sans-15px-black-70%']").text
            pres_dur = driver.find_element_by_xpath("//span[@class='pv-entity__bullet-item']").text
            pres_loc = driver.find_element_by_xpath("//h4[@class='pv-entity__location Sans-15px-black-70% block']").text
            pres_des = driver.find_element_by_xpath("//p[@class='pv-entity__description Sans-15px-black-70% mt4']").text
            
    except:
            description = ''
            pres_title = ''
            pres_company = ''
            pres_date = ''
            pres_dur = ''
            pres_loc = ''
            pres_des = ''
    
    datastore = {
             'Name': name,
             'Headline': headline, 
             'Location': location, 
             'Description': description, 
             'Present Job Title': pres_title,
             'Company': pres_company,
             'Date': pres_date,
             'Duration': pres_dur,
             'Loc': pres_loc,
             'Des': pres_des,}


    print(name, 
          "\n" + headline, 
          "\n" + location, 
          "\n" + description, 
          "\n" + pres_title,
          "\n" + pres_company,
          "\n" + pres_date,
          "\n" + pres_dur,
          "\n" + pres_loc,
          "\n" + pres_des    
         
         + "\n")
        
# sending a msg
#     driver.find_element_by_css_selector('.pv-s-profile-actions.pv-s-profile-actions--connect.button-primary-large.mr2.mt2').click()
#     driver.find_element_by_css_selector('.button-secondary-large.mr1').click()

#     note = driver.find_element_by_id("custom-message")
#     note.send_keys("Hey "+ name +", came across your profile as I was connecting with a friend" +
#                    "from " + location+". Took a look at "+pres_company+" and found it interesting. I personally" +
#                    "help growth companies land more sales meetings. If you're game, let's chat upon connecting!")
# Out:
# Declan O'Boyle
# Financial Consultant and CFO
# Ireland
# I am an experienced Financial Consultant / CFO with strong Strategic, Financial, Commercial and Corporate Governance skills. A leader with good interpersonal skills who is capable of working on own initiative. An excellent communicator who is deadline and results driven and committed to high stand...
# Senior Financial Consultant
# Anois Consulting Limited
# Dates Employed
# Aug 2017 – Present
# 1 yr
# Location
# Drogheda, Co. Louth
# I have re-established Anois Consulting to help businesses who require an experienced Financial Consultant / CFO with strong Strategic, Financial, Commercial and Corporate Governance skills. Key current assignments includes:
# * Financial health check and strategic review of a HR Services company along with on going CFO services
# * Financial review and restructuring of a Property Investment company
# * Development of a Business plan for a new Hotel and Leisure Centre on the Wild Atlantic Way
#
# Steven M. Graf
# CFO/Controller at Maverick Aviation Group
# Las Vegas, Nevada Area
#
#
#
#
#
#
#
#
# Robert Townsend
# CFO/Controller at Maverick Aviation Group
# Las Vegas, Nevada Area
# ---------------------------------------------------------------------------
# CannotSendRequest                         Traceback (most recent call last)
# <ipython-input-6-2c546fd747b7> in <module>()
#       2 # while (i < 3):
#       3 for x in df["Person Linkedin Url"].tolist():
# ----> 4     driver.get(x)
#       5     time.sleep(10)
#       6 #     i = i + 1
#
# ~/Envs/test-venv/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     330         Loads a web page in the current browser session.
#     331         """
# --> 332         self.execute(Command.GET, {'url': url})
#     333
#     334     @property
#
# ~/Envs/test-venv/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     316
#     317         params = self._wrap_value(params)
# --> 318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
#     320             self.error_handler.check_response(response)
#
# ~/Envs/test-venv/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     470         data = utils.dump_json(params)
#     471         url = '%s%s' % (self._url, path)
# --> 472         return self._request(command_info[0], url, body=data)
#     473
#     474     def _request(self, method, url, body=None):
#
# ~/Envs/test-venv/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     493                 body = None
#     494             try:
# --> 495                 self._conn.request(method, parsed_url.path, body, headers)
#     496                 resp = self._conn.getresponse()
#     497             except (httplib.HTTPException, socket.error):
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1238             skips['skip_accept_encoding'] = 1
#    1239
# -> 1240         self.putrequest(method, url, **skips)
#    1241
#    1242         # chunked encoding will happen if HTTP/1.1 is used and either
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in putrequest(self, method, url, skip_host, skip_accept_encoding)
#    1096             self.__state = _CS_REQ_STARTED
#    1097         else:
# -> 1098             raise CannotSendRequest(self.__state)
#    1099
#    1100         # Save the method we use, we need it later in the response phase
#
# CannotSendRequest: Request-sent
